# %%
import matplotlib.pyplot as plt

# %%
x = [2, 4, 6]
y = [1, 3, 5]
plt.plot(x, y)
plt.show()

# %%
pd.read_csv("https://oceanview.pfeg.noaa.gov/erddap/griddap/erdUI39mo.htmlTable?upwelling_index%5B(1950-08-15T00:00:00Z):1:(2018-08-15T00:00:00Z)%5D%5B(39.0):1:(39.0)%5D%5B(235.0):1:(235.0)%5D%2Cupwelling_index_anomaly%5B(1950-08-15T00:00:00Z):1:(2018-08-15T00:00:00Z)%5D%5B(39.0):1:(39.0)%5D%5B(235.0):1:(235.0)%5D")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d0ff86608922> in <module>()
# ----> 1 pd.read_csv("https://oceanview.pfeg.noaa.gov/erddap/griddap/erdUI39mo.htmlTable?upwelling_index%5B(1950-08-15T00:00:00Z):1:(2018-08-15T00:00:00Z)%5D%5B(39.0):1:(39.0)%5D%5B(235.0):1:(235.0)%5D%2Cupwelling_index_anomaly%5B(1950-08-15T00:00:00Z):1:(2018-08-15T00:00:00Z)%5D%5B(39.0):1:(39.0)%5D%5B(235.0):1:(235.0)%5D")
#
# NameError: name 'pd' is not defined

# %%
pd.read_csv("oceanview.pfeg.noaa.gov/erddap/griddap/erdUI39mo.htmlTable")

# %%
import pandas as pd

# %%
pd.read_csv("upwelling.csv")

# %%
df = pd.read_csv("upwelling.csv")

# %%
import pandas as pd

# %%
df.upwelling_index.value_counts().reset_index()

# %%
import matplotlib.pyplot as pls

# %%
df.plot(x='time', y='upwelling_index', style='k-')

# %%
from pandas import Series
from pandas import DataFrame
from pandas import TimeGrouper
from matplotlib import pyplot

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from datetime import datetime
import pandas_datareader.data as web

# %%
df['upwelling'].filter(lambda x: re.match('-05-10$', x))

# %%
df.info

# %%
upwell.info

# %%
df.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-113d0d74a86b> in <module>()
# ----> 1 df.info
#
# NameError: name 'df' is not defined

# %%
upwelling.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cbdda5198548> in <module>()
# ----> 1 upwelling.info
#
# NameError: name 'upwelling' is not defined

# %%
upwell.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c18d58909d03> in <module>()
# ----> 1 upwell.info
#
# NameError: name 'upwell' is not defined

# %%
import pandas as pd

# %%
pd.read_csv("upwelling.csv")
# Out:
#                      time  latitude_degrees_north  longitude_ degrees_east  \
# 0    1950-08-15T00:00:00Z                    39.0                    235.0
# 1    1950-09-15T00:00:00Z                    39.0                    235.0
# 2    1950-10-15T00:00:00Z                    39.0                    235.0
# 3    1950-11-15T00:00:00Z                    39.0                    235.0
# 4    1950-12-15T00:00:00Z                    39.0                    235.0
# 5    1951-01-15T00:00:00Z                    39.0                    235.0
# 6    1951-02-15T00:00:00Z                    39.0                    235.0
# 7    1951-03-15T00:00:00Z                    39.0                    235.0
# 8    1951-04-15T00:00:00Z                    39.0                    235.0
# 9    1951-05-15T00:00:00Z                    39.0                    235.0
# 10   1951-06-15T00:00:00Z                    39.0                    235.0
# ...

# %%
df = pd.read_csv("upwelling.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of                      time  latitude_degrees_north  longitude_ degrees_east  \
# 0    1950-08-15T00:00:00Z                    39.0                    235.0
# 1    1950-09-15T00:00:00Z                    39.0                    235.0
# 2    1950-10-15T00:00:00Z                    39.0                    235.0
# 3    1950-11-15T00:00:00Z                    39.0                    235.0
# 4    1950-12-15T00:00:00Z                    39.0                    235.0
# 5    1951-01-15T00:00:00Z                    39.0                    235.0
# 6    1951-02-15T00:00:00Z                    39.0                    235.0
# 7    1951-03-15T00:00:00Z                    39.0                    235.0
# 8    1951-04-15T00:00:00Z                    39.0                    235.0
# 9    1951-05-15T00:00:00Z                    39.0                    235.0
# 10   1951-06-15T00:00:00Z                    39.0                    235.0
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                      time  latitude_degrees_north  longitude_ degrees_east  \
# 0    1950-08-15T00:00:00Z                    39.0                    235.0
# 1    1950-09-15T00:00:00Z                    39.0                    235.0
# 2    1950-10-15T00:00:00Z                    39.0                    235.0
# 3    1950-11-15T00:00:00Z                    39.0                    235.0
# 4    1950-12-15T00:00:00Z                    39.0                    235.0
# 5    1951-01-15T00:00:00Z                    39.0                    235.0
# 6    1951-02-15T00:00:00Z                    39.0                    235.0
# 7    1951-03-15T00:00:00Z                    39.0                    235.0
# 8    1951-04-15T00:00:00Z                    39.0                    235.0
# 9    1951-05-15T00:00:00Z                    39.0                    235.0
# 10   1951-06-15T00:00:00Z                    39.0                    235.0
# ...

# %%
df = pd.read_csv('upwelling.csv',parse_dates=True)

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.loc['xxxx-04-xxxxx:xx:00Z':'xxxx-10-xxxxx:xx:00Z']
# Out:
# Empty DataFrame
# Columns: [time, latitude_degrees_north, longitude_ degrees_east, upwelling_index, upwelling_index_anomaly, Unnamed: 5, Unnamed: 6]
# Index: []

# %%
df = DataFrame({'time':[datetime(2018-08-15).date() + timedelta(month=m) for m in range(0,12*2)], 'xmas':np.zeros(12*2)})

df[df['date'].month==04 and df['time'] = 1
# Out:
#   File "<ipython-input-18-81d16ab46add>", line 1
#     df = DataFrame({'time':[datetime(2018-08-15).date() + timedelta(month=m) for m in range(0,12*2)], 'xmas':np.zeros(12*2)})
#                                            ^
# SyntaxError: invalid token

# %%
import datetime

# %%
d1 = datetime.datetime.strptime("1950-08-15T00:00:00Z","%Y-%m-%dT%H:%M:%SZ")

# %%
new_format = "%Y-%m-%d"
d1.strftime(new_format)
# Out:
# '1950-08-15'

# %%
import numpy
import dateutil.parser
mydate = dateutil.parser.parse(numpy.mydata[1:,0])
print(mydate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-1e52a3269d1c> in <module>()
#       1 import numpy
#       2 import dateutil.parser
# ----> 3 mydate = dateutil.parser.parse(numpy.mydata[1:,0])
#       4 print(mydate)
#
# AttributeError: module 'numpy' has no attribute 'mydata'

# %%
df = pd.read_csv('upwelling.csv', parse_dates=True)

# %%
import datetime, timedelta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-857634dddb7b> in <module>()
# ----> 1 import datetime, timedelta
#
# ModuleNotFoundError: No module named 'timedelta'

# %%
dates = ["1950-08-15T00:00:00Z", "2018-08-15T00:00:00Z"]

# %%
from datetime import datetime, timedelta

# %%
from collections import OrderedDict

# %%
start, end = [datetime.strptime(_, "%Y-%m-%dT%H:%M:%SZ") for _ in dates]

# %%
pd.date_range("1950-08-15T00:00:00Z","2018-08-15T00:00:00Z", 
              freq='MS').strftime("%Y-%b").tolist()
# Out:
# ['1950-Sep',
#  '1950-Oct',
#  '1950-Nov',
#  '1950-Dec',
#  '1951-Jan',
#  '1951-Feb',
#  '1951-Mar',
#  '1951-Apr',
#  '1951-May',
#  '1951-Jun',
#  '1951-Jul',
#  '1951-Aug',
#  '1951-Sep',
#  '1951-Oct',
#  '1951-Nov',
#  '1951-Dec',
#  '1952-Jan',
#  '1952-Feb',
#  '1952-Mar',
#  '1952-Apr',
#  '1952-May',
#  '1952-Jun',
#  '1952-Jul',
#  '1952-Aug',
#  '1952-Sep',
#  '1952-Oct',
#  '1952-Nov',
#  '1952-Dec',
#  '1953-Jan',
#  '1953-Feb',
#  '1953-Mar',
#  '1953-Apr',
#  '1953-May',
#  '1953-Jun',
#  '1953-Jul',
#  '1953-Aug',
#  '1953-Sep',
#  '1953-Oct',
#  '1953-Nov',
#  '1953-Dec',
#  '1954-Jan',
#  '1954-Feb',
#  '1954-Mar',
#  '1954-Apr',
#  '1954-May',
#  '1954-Jun',
#  '1954-Jul',
#  '1954-Aug',
#  '1954-Sep',
#  '1954-Oct',
#  '1954-Nov',
#  '1954-Dec',
#  '1955-Jan',
#  '1955-Feb',
#  '1955-Mar',
#  '1955-Apr',
#  '1955-May',
#  '1955-Jun',
#  '1955-Jul',
#  '1955-Aug',
#  '1955-Sep',
#  '1955-Oct',
#  '1955-Nov',
#  '1955-Dec',
#  '1956-Jan',
#  '1956-Feb',
# ...

# %%
import dateutil

# %%
import numpy as np

# %%
df.head(3)
# Out:
#                        time  latitude_degrees_north  longitude_ degrees_east  \
# 0 1950-08-15 00:00:00+00:00                    39.0                    235.0
# 1 1950-09-15 00:00:00+00:00                    39.0                    235.0
# 2 1950-10-15 00:00:00+00:00                    39.0                    235.0
#
#    upwelling_index  upwelling_index_anomaly  Unnamed: 5  Unnamed: 6
# 0            269.0                     86.0         NaN         NaN
# 1            219.0                    126.0         NaN         NaN
# 2             75.0                     26.0         NaN         NaN

# %%
df.dtypes
# Out:
# time                       datetime64[ns, UTC]
# latitude_degrees_north                 float64
# longitude_ degrees_east                float64
# upwelling_index                        float64
# upwelling_index_anomaly                float64
# Unnamed: 5                             float64
# Unnamed: 6                             float64
# dtype: object

# %%
dt64 = numpy.datetime64('2002-06-28T01:00:00.000000000+0100')
# Out:
# /Users/steveluxenberg/Code/first-python-notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   """Entry point for launching an IPython kernel.

# %%
dt = datetime.utcnow()

# %%
df.head(3)
# Out:
#                        time  latitude_degrees_north  longitude_ degrees_east  \
# 0 1950-08-15 00:00:00+00:00                    39.0                    235.0
# 1 1950-09-15 00:00:00+00:00                    39.0                    235.0
# 2 1950-10-15 00:00:00+00:00                    39.0                    235.0
#
#    upwelling_index  upwelling_index_anomaly  Unnamed: 5  Unnamed: 6
# 0            269.0                     86.0         NaN         NaN
# 1            219.0                    126.0         NaN         NaN
# 2             75.0                     26.0         NaN         NaN

# %%
df.dtypes
# Out:
# time                       datetime64[ns, UTC]
# latitude_degrees_north                 float64
# longitude_ degrees_east                float64
# upwelling_index                        float64
# upwelling_index_anomaly                float64
# Unnamed: 5                             float64
# Unnamed: 6                             float64
# dtype: object

# %%
https://stepik.org/lesson/44678/step/1?unit=22718
